# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np

# %% [markdown]
# # 1. Open the categorical dataframe we created before.

# %%
categorical_df = pd.read_csv('categorical.csv')
display(categorical_df.shape)
categorical_df.head()
# Out:
# (9134, 14)
#         state response  coverage education employmentstatus gender  \
# 0  Washington       No         1  Bachelor         Employed      F
# 1     Arizona       No         2  Bachelor       Unemployed      F
# 2      Nevada       No         3  Bachelor         Employed      F
# 3  California       No         1  Bachelor       Unemployed      M
# 4  Washington       No         1  Bachelor         Employed      M
#
#   location_code marital_status policy_type renew_offer_type sales_channel  \
# 0      Suburban        Married           C               O1         Agent
# 1      Suburban         Single           P               O3         Agent
# 2      Suburban        Married           P               O1         Agent
# 3      Suburban        Married           C               O1   Call Center
# 4         Rural         Single           P               O1         Agent
#
#    vehicle_class  vehicle_size  policy_level
# 0   Two-Door Car             2             3
# ...

# %% [markdown]
# # 2. Plot all the categorical variables with the proper plot. What can you see?

# %%
for column in categorical_df:
    sns.countplot(data=categorical_df, x=column)
    plt.show()

# %%
# the categorical column plots seem easy to understand and representative on the stored information.

# %% [markdown]
# # 3. There might be some columns that seem to be redundant, check their values to be sure. What should we do with them?

# %%
# I don't think there is any need to clean the columns more.

# %% [markdown]
# # 4. Plot time variable. Can you extract something from it?

# %%
customer_df=pd.read_csv('we_fn_use_c_marketing_customer_value_analysis (1).csv')
customer_df
# Out:
#      Customer       State  Customer Lifetime Value Response  Coverage  \
# 0     BU79786  Washington              2763.519279       No     Basic
# 1     QZ44356     Arizona              6979.535903       No  Extended
# 2     AI49188      Nevada             12887.431650       No   Premium
# 3     WW63253  California              7645.861827       No     Basic
# 4     HB64268  Washington              2813.692575       No     Basic
# ...       ...         ...                      ...      ...       ...
# 9129  LA72316  California             23405.987980       No     Basic
# 9130  PK87824  California              3096.511217      Yes  Extended
# 9131  TD14365  California              8163.890428       No  Extended
# 9132  UP19263  California              7524.442436       No  Extended
# 9133  Y167826  California              2611.836866       No  Extended
#
#      Education Effective To Date EmploymentStatus Gender  Income  ...  \
# ...

# %%
customer_df['Effective To Date']
# Out:
# 0       2/24/11
# 1       1/31/11
# 2       2/19/11
# 3       1/20/11
# 4        2/3/11
#          ...
# 9129    2/10/11
# 9130    2/12/11
# 9131     2/6/11
# 9132     2/3/11
# 9133    2/14/11
# Name: Effective To Date, Length: 9134, dtype: object

# %%
sns.countplot(x=customer_df['Effective To Date'])
plt.show()
